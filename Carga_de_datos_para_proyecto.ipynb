# %% [markdown]
# <a href="https://colab.research.google.com/github/Henao/python-samples/blob/master/Carga_de_datos_para_proyecto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
import csv

# %%
## Permite renderizar gráficos directamente en Notebook
##Carga en pandas dataframe la base de datos
## comando jupyter magics
# %matplotlib inline

# %% [markdown]
# Carga en un pandas dataframe de BD

# %%
movies = pd.read_csv('https://github.com/JuanPabloMF/datasets-platzi-course/blob/master/datasets/peliculas.csv?raw=true',encoding='utf-8')

# %%
type(movies)
# Out:
# pandas.core.frame.DataFrame

# %%
movies.head()
# Out:
#                                          movie_title  ...        gross
# 0                                            Avatar   ...  760505847.0
# 1          Pirates of the Caribbean: At World's End   ...  309404152.0
# 2                                           Spectre   ...  200074175.0
# 3                             The Dark Knight Rises   ...  448130642.0
# 4  Star Wars: Episode VII - The Force Awakens    ...  ...          NaN
#
# [5 rows x 19 columns]

# %% [markdown]
# Dimensión: Lineas y Columnas que tiene

# %%
movies.shape
# Out:
# (5043, 19)

# %% [markdown]
# ![array.JPG](data:image/jpeg;base64,...)

# %%
movies.columns
# Out:
# Index(['movie_title', 'title_year', 'color', 'aspect_ratio', 'duration',
#        'language', 'country', 'duration.1', 'genres', 'content_rating',
#        'plot_keywords', 'director_name', 'actor_1_name', 'actor_2_name',
#        'actor_3_name', 'cast_total_facebook_likes', 'budget', 'imdb_score',
#        'gross'],
#       dtype='object')

# %%
movies.index
# Out:
# RangeIndex(start=0, stop=5043, step=1)

# %%
columna = movies['movie_title']
columna.head()
# Out:
# 0                                              Avatar
# 1            Pirates of the Caribbean: At World's End
# 2                                             Spectre
# 3                               The Dark Knight Rises
# 4    Star Wars: Episode VII - The Force Awakens    ...
# Name: movie_title, dtype: object

# %%
linea = movies.loc[25,:]
linea
# Out:
# movie_title                                                         King Kong
# title_year                                                                2005
# color                                                                    Color
# aspect_ratio                                                              2.35
# duration                                                                   201
# language                                                               English
# country                                                            New Zealand
# duration.1                                                                 201
# genres                                          Action|Adventure|Drama|Romance
# content_rating                                                           PG-13
# plot_keywords                animal name in title|ape abducts a woman|goril...
# director_name                                                    Peter Jackson
# ...

# %%
movies['movie_title']
# Out:
# 0                                                 Avatar
# 1               Pirates of the Caribbean: At World's End
# 2                                                Spectre
# 3                                  The Dark Knight Rises
# 4       Star Wars: Episode VII - The Force Awakens    ...
#                               ...
# 5038                             Signed Sealed Delivered
# 5039                           The Following
# 5040                                A Plague So Pleasant
# 5041                                    Shanghai Calling
# 5042                                   My Date with Drew
# Name: movie_title, Length: 5043, dtype: object

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5043 entries, 0 to 5042
# Data columns (total 19 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   movie_title                5043 non-null   object
#  1   title_year                 4935 non-null   float64
#  2   color                      5024 non-null   object
#  3   aspect_ratio               4714 non-null   float64
#  4   duration                   5028 non-null   float64
#  5   language                   5031 non-null   object
#  6   country                    5038 non-null   object
#  7   duration.1                 5028 non-null   float64
#  8   genres                     5043 non-null   object
#  9   content_rating             4740 non-null   object
#  10  plot_keywords              4890 non-null   object
#  11  director_name              4939 non-null   object
#  12  actor_1_name               5036 non-null   object
# ...

# %%
#Columnas numericas y columnas de teto
movies.dtypes == float
# Out:
# movie_title                  False
# title_year                    True
# color                        False
# aspect_ratio                  True
# duration                      True
# language                     False
# country                      False
# duration.1                    True
# genres                       False
# content_rating               False
# plot_keywords                False
# director_name                False
# actor_1_name                 False
# actor_2_name                 False
# actor_3_name                 False
# cast_total_facebook_likes    False
# budget                        True
# imdb_score                    True
# gross                         True
# dtype: bool

# %%
(movies.dtypes ==float) | (movies.dtypes == int)
# Out:
# movie_title                  False
# title_year                    True
# color                        False
# aspect_ratio                  True
# duration                      True
# language                     False
# country                      False
# duration.1                    True
# genres                       False
# content_rating               False
# plot_keywords                False
# director_name                False
# actor_1_name                 False
# actor_2_name                 False
# actor_3_name                 False
# cast_total_facebook_likes     True
# budget                        True
# imdb_score                    True
# gross                         True
# dtype: bool

# %%
movies.dtypes == object
# Out:
# movie_title                   True
# title_year                   False
# color                         True
# aspect_ratio                 False
# duration                     False
# language                      True
# country                       True
# duration.1                   False
# genres                        True
# content_rating                True
# plot_keywords                 True
# director_name                 True
# actor_1_name                  True
# actor_2_name                  True
# actor_3_name                  True
# cast_total_facebook_likes    False
# budget                       False
# imdb_score                   False
# gross                        False
# dtype: bool

# %%
num = (movies.dtypes == float) | (movies.dtypes == int)
num
# Out:
# movie_title                  False
# title_year                    True
# color                        False
# aspect_ratio                  True
# duration                      True
# language                     False
# country                      False
# duration.1                    True
# genres                       False
# content_rating               False
# plot_keywords                False
# director_name                False
# actor_1_name                 False
# actor_2_name                 False
# actor_3_name                 False
# cast_total_facebook_likes     True
# budget                        True
# imdb_score                    True
# gross                         True
# dtype: bool

# %%
num.index
# Out:
# Index(['movie_title', 'title_year', 'color', 'aspect_ratio', 'duration',
#        'language', 'country', 'duration.1', 'genres', 'content_rating',
#        'plot_keywords', 'director_name', 'actor_1_name', 'actor_2_name',
#        'actor_3_name', 'cast_total_facebook_likes', 'budget', 'imdb_score',
#        'gross'],
#       dtype='object')

# %%
for el in num:
   print(el)
# Out:
# False
# True
# False
# True
# True
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# True
# True
# True
# True

# %%
num_cols = [c for c in num.index if num[c]]
num_cols
# Out:
# ['title_year',
#  'aspect_ratio',
#  'duration',
#  'duration.1',
#  'cast_total_facebook_likes',
#  'budget',
#  'imdb_score',
#  'gross']

# %% [markdown]
# [c for c num.index] obtiene las columnas en num.index las agrega en la lista solo las columnas con valor true con [c]

# %%
for el in num.index:
  print(el)
# Out:
# movie_title
# title_year
# color
# aspect_ratio
# duration
# language
# country
# duration.1
# genres
# content_rating
# plot_keywords
# director_name
# actor_1_name
# actor_2_name
# actor_3_name
# cast_total_facebook_likes
# budget
# imdb_score
# gross

# %%
movies.dtypes == object
# Out:
# movie_title                   True
# title_year                   False
# color                         True
# aspect_ratio                 False
# duration                     False
# language                      True
# country                       True
# duration.1                   False
# genres                        True
# content_rating                True
# plot_keywords                 True
# director_name                 True
# actor_1_name                  True
# actor_2_name                  True
# actor_3_name                  True
# cast_total_facebook_likes    False
# budget                       False
# imdb_score                   False
# gross                        False
# dtype: bool

# %%
obj = (movies.dtypes == object)
obj_cols = [c for c in obj.index if obj[c]]

# %%
obj_cols
# Out:
# ['movie_title',
#  'color',
#  'language',
#  'country',
#  'genres',
#  'content_rating',
#  'plot_keywords',
#  'director_name',
#  'actor_1_name',
#  'actor_2_name',
#  'actor_3_name']

# %%
num_cols
# Out:
# ['title_year',
#  'aspect_ratio',
#  'duration',
#  'duration.1',
#  'cast_total_facebook_likes',
#  'budget',
#  'imdb_score',
#  'gross']

# %%
movies_num = movies[num_cols]
movies_num
# Out:
#       title_year  aspect_ratio  duration  ...       budget  imdb_score        gross
# 0         2009.0          1.78     178.0  ...  237000000.0         7.9  760505847.0
# 1         2007.0          2.35     169.0  ...  300000000.0         7.1  309404152.0
# 2         2015.0          2.35     148.0  ...  245000000.0         6.8  200074175.0
# 3         2012.0          2.35     164.0  ...  250000000.0         8.5  448130642.0
# 4            NaN           NaN       NaN  ...          NaN         7.1          NaN
# ...          ...           ...       ...  ...          ...         ...          ...
# 5038      2013.0           NaN      87.0  ...          NaN         7.7          NaN
# 5039         NaN         16.00      43.0  ...          NaN         7.5          NaN
# 5040      2013.0           NaN      76.0  ...       1400.0         6.3          NaN
# 5041      2012.0          2.35     100.0  ...          NaN         6.3      10443.0
# ...

# %% [markdown]
# Método describe(): Para cada columna, da todas las propiedades estadísticas si es una columna numérica, si hay alguna de texto entre las numéricas nos daría menos información.

# %%
## Estadisticas de las columnas numericas
movies_num.describe()
# Out:
#         title_year  aspect_ratio  ...   imdb_score         gross
# count  4935.000000   4714.000000  ...  5043.000000  4.159000e+03
# mean   2002.470517      2.220403  ...     6.442138  4.846841e+07
# std      12.474599      1.385113  ...     1.125116  6.845299e+07
# min    1916.000000      1.180000  ...     1.600000  1.620000e+02
# 25%    1999.000000      1.850000  ...     5.800000  5.340988e+06
# 50%    2005.000000      2.350000  ...     6.600000  2.551750e+07
# 75%    2011.000000      2.350000  ...     7.200000  6.230944e+07
# max    2016.000000     16.000000  ...     9.500000  7.605058e+08
#
# [8 rows x 8 columns]

# %%
movies_num['duration'].hist()

# %%
movies_num['imdb_score'].hist(bins=100)

# %%
movies_num['budget'].hist()

# %%
(movies_num['budget'] > 1e9).value_counts()
# Out:
# False    5037
# True        6
# Name: budget, dtype: int64

# %%
msk = (movies_num['budget'] > 1e9)

# %%
movies[msk]
# Out:
#              movie_title  title_year  ... imdb_score      gross
# 2323  Princess Mononoke       1997.0  ...        8.4  2298191.0
# 2334           Steamboy       2004.0  ...        6.9   410388.0
# 2988           The Host       2006.0  ...        7.0  2201412.0
# 3005           Fateless       2005.0  ...        7.1   195888.0
# 3423              Akira       1988.0  ...        8.1   439162.0
# 3859     Lady Vengeance       2005.0  ...        7.7   211667.0
#
# [6 rows x 19 columns]

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
with open('/gdrive/My Drive/csv-colab/movies_num_cols.csv', 'w') as f:
  movies_num.to_csv(f)

# %%
pd.read_csv('https://github.com/JuanPabloMF/datasets-platzi-course/blob/master/datasets/thenumbers.csv?raw=true', encoding='utf-8')
# Out:
#       Unnamed: 0  ...                                        movie_title
# 0              0  ...                                            Avatar
# 1              1  ...  Star Wars: Episode VII - The Force Awakens    ...
# 2              2  ...          Pirates of the Caribbean: At World's End
# 3              3  ...                                           Spectre
# 4              4  ...                             The Dark Knight Rises
# ...          ...  ...                                                ...
# 4336        5157  ...                                   The Mongol King
# 4337        5160  ...                           Signed Sealed Delivered
# 4338        5161  ...                                  Shanghai Calling
# 4339        5162  ...                              A Plague So Pleasant
# 4340        5163  ...                                 My Date with Drew
#
# [4341 rows x 8 columns]

# %%
financials = pd.read_csv('https://github.com/JuanPabloMF/datasets-platzi-course/blob/master/datasets/thenumbers.csv?raw=true')

# %%
financials = financials[['movie_title', 'production_budget', 'worldwide_gross']]
financials
# Out:
#                                             movie_title  ...  worldwide_gross
# 0                                               Avatar   ...       2783918982
# 1     Star Wars: Episode VII - The Force Awakens    ...  ...       2058662225
# 2             Pirates of the Caribbean: At World's End   ...        963420425
# 3                                              Spectre   ...        879620923
# 4                                The Dark Knight Rises   ...       1084439099
# ...                                                 ...  ...              ...
# 4336                                   The Mongol King   ...              900
# 4337                           Signed Sealed Delivered   ...                0
# 4338                                  Shanghai Calling   ...            10443
# 4339                              A Plague So Pleasant   ...                0
# 4340                                 My Date with Drew   ...           181041
#
# [4341 rows x 3 columns]

# %%
movies.shape
# Out:
# (5043, 19)

# %%
financials.shape
# Out:
# (4341, 8)

# %%
movies_num
# Out:
#       title_year  aspect_ratio  duration  ...       budget  imdb_score        gross
# 0         2009.0          1.78     178.0  ...  237000000.0         7.9  760505847.0
# 1         2007.0          2.35     169.0  ...  300000000.0         7.1  309404152.0
# 2         2015.0          2.35     148.0  ...  245000000.0         6.8  200074175.0
# 3         2012.0          2.35     164.0  ...  250000000.0         8.5  448130642.0
# 4            NaN           NaN       NaN  ...          NaN         7.1          NaN
# ...          ...           ...       ...  ...          ...         ...          ...
# 5038      2013.0           NaN      87.0  ...          NaN         7.7          NaN
# 5039         NaN         16.00      43.0  ...          NaN         7.5          NaN
# 5040      2013.0           NaN      76.0  ...       1400.0         6.3          NaN
# 5041      2012.0          2.35     100.0  ...          NaN         6.3      10443.0
# ...

# %%
movies['movie_title']
# Out:
# 0                                                 Avatar
# 1               Pirates of the Caribbean: At World's End
# 2                                                Spectre
# 3                                  The Dark Knight Rises
# 4       Star Wars: Episode VII - The Force Awakens    ...
#                               ...
# 5038                             Signed Sealed Delivered
# 5039                           The Following
# 5040                                A Plague So Pleasant
# 5041                                    Shanghai Calling
# 5042                                   My Date with Drew
# Name: movie_title, Length: 5043, dtype: object

# %% [markdown]
# para hacer concatenación columna por columna agregamos , axis=1

# %%
movies_num_b = pd.concat([movies_num, movies['movie_title']], axis=1)

# %%
movies_v2 = pd.merge(financials,movies_num_b,on='movie_title',how='left')

# %%
movies_v2.shape
# Out:
# (4385, 16)

# %%
help(pd.Series.value_counts)
# Out:
# Help on function value_counts in module pandas.core.base:
#
# value_counts(self, normalize=False, sort=True, ascending=False, bins=None, dropna=True)
#     Return a Series containing counts of unique values.
#
#     The resulting object will be in descending order so that the
#     first element is the most frequently-occurring element.
#     Excludes NA values by default.
#
#     Parameters
#     ----------
#     normalize : bool, default False
#         If True then the object returned will contain the relative
#         frequencies of the unique values.
#     sort : bool, default True
#         Sort by frequencies.
#     ascending : bool, default False
#         Sort in ascending order.
#     bins : int, optional
#         Rather than count values, group them into half-open bins,
#         a convenience for ``pd.cut``, only works with numeric data.
#     dropna : bool, default True
#         Don't include counts of NaN.
#
#     Returns
#     -------
#     Series
#
#     See Also
# ...

# %%
movies_v2.notnull().apply(pd.Series.value_counts)
# Out:
#        Unnamed: 0  movie_name  domestic_gross  ...  budget  imdb_score  gross
# False         NaN         NaN             NaN  ...     335         NaN    671
# True       4385.0      4385.0          4385.0  ...    4050      4385.0   3714
#
# [2 rows x 16 columns]

# %%
(movies_v2 != 0).apply(pd.Series.value_counts)
# Out:
#        Unnamed: 0  movie_name  domestic_gross  ...  budget  imdb_score   gross
# False           1         NaN             376  ...     NaN         NaN     NaN
# True         4384      4385.0            4009  ...  4385.0      4385.0  4385.0
#
# [2 rows x 16 columns]

# %%
available = ((movies_v2 != 0) & (movies_v2.notnull()))

# %%
available
# Out:
#       Unnamed: 0  movie_name  domestic_gross  ...  budget  imdb_score  gross
# 0          False        True            True  ...    True        True   True
# 1           True        True            True  ...   False        True  False
# 2           True        True            True  ...    True        True   True
# 3           True        True            True  ...    True        True   True
# 4           True        True            True  ...    True        True   True
# ...          ...         ...             ...  ...     ...         ...    ...
# 4380        True        True            True  ...    True        True  False
# 4381        True        True           False  ...   False        True  False
# 4382        True        True            True  ...   False        True   True
# 4383        True        True           False  ...    True        True  False
# 4384        True        True            True  ...    True        True   True
#
# [4385 rows x 16 columns]

# %%
available.all(axis=1).value_counts()
# Out:
# True     3407
# False     978
# dtype: int64

# %%
mask2 = available['worldwide_gross']

# %%
movies_v2 = movies_v2[mask2]

# %%
mask2
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 4380     True
# 4381    False
# 4382     True
# 4383    False
# 4384     True
# Name: worldwide_gross, Length: 4385, dtype: bool

# %%
((movies_v2 != 0) & (movies_v2.notnull())).worldwide_gross.value_counts()
# Out:
# True    4104
# Name: worldwide_gross, dtype: int64

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(missing_values=np.nan, strategy='mean')

# %%
movies_v2
# Out:
#       Unnamed: 0  ...        gross
# 0              0  ...  760505847.0
# 1              1  ...          NaN
# 2              2  ...  309404152.0
# 3              3  ...  200074175.0
# 4              4  ...  448130642.0
# ...          ...  ...          ...
# 4378        5155  ...     424760.0
# 4379        5156  ...      70071.0
# 4380        5157  ...          NaN
# 4382        5161  ...      10443.0
# 4384        5163  ...      85222.0
#
# [4104 rows x 14 columns]

# %%
movies_v2 = movies_v2.drop('movie_title', axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-77-f7effe5c7409> in <module>()
# ----> 1 movies_v2 = movies_v2.drop('movie_title', axis=1)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4168             level=level,
#    4169             inplace=inplace,
# -> 4170             errors=errors,
#    4171         )
#    4172
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3885         for axis, labels in axes.items():
#    3886             if labels is not None:
# -> 3887                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3888
#    3889         if inplace:
#
# ...

# %%
movies_v2 = movies_v2.drop('duration', axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-70-8464e0a3d52b> in <module>()
# ----> 1 movies_v2 = movies_v2.drop('duration', axis=1)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4168             level=level,
#    4169             inplace=inplace,
# -> 4170             errors=errors,
#    4171         )
#    4172
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3885         for axis, labels in axes.items():
#    3886             if labels is not None:
# -> 3887                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3888
#    3889         if inplace:
#
# ...

# %%
movies_v2.head()
# Out:
#    Unnamed: 0  ...        gross
# 0           0  ...  760505847.0
# 1           1  ...          NaN
# 2           2  ...  309404152.0
# 3           3  ...  200074175.0
# 4           4  ...  448130642.0
#
# [5 rows x 14 columns]

# %%
values = imputer.fit_transform(movies_v2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-72-070eff5d2c76> in <module>()
# ----> 1 values = imputer.fit_transform(movies_v2)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/base.py in fit_transform(self, X, y, **fit_params)
#     569         if y is None:
#     570             # fit method of arity 1 (unsupervised transformation)
# --> 571             return self.fit(X, **fit_params).transform(X)
#     572         else:
#     573             # fit method of arity 2 (supervised transformation)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/impute/_base.py in fit(self, X, y)
#     266         self : SimpleImputer
#     267         """
# --> 268         X = self._validate_input(X)
#     269         super()._fit_indicator(X)
#     270
#
# /usr/local/lib/python3.6/dist-packages/sklearn/impute/_base.py in _validate_input(self, X)
# ...

# %%
values = movies_v2.values

# %%
values
# Out:
# array([[0, 'Avatar', 760507625, ..., 237000000.0, 7.9, 760505847.0],
#        [1, 'Star Wars Ep. VII: The Force Awakens', 936662225, ..., nan,
#         7.1, nan],
#        [2, "Pirates of the Caribbean: At World's End", 309420425, ...,
#         300000000.0, 7.1, 309404152.0],
#        ...,
#        [5157, 'The Mongol King', 900, ..., 3250.0, 7.8, nan],
#        [5161, 'Shanghai Calling', 10443, ..., nan, 6.3, 10443.0],
#        [5163, 'My Date With Drew', 181041, ..., 1100.0, 6.6, 85222.0]],
#       dtype=object)

# %%
X = pd.DataFrame(values)

# %%
X.columns = movies_v2.columns

# %%
X.index = movies_v2.index

# %%
X.head()
# Out:
#   Unnamed: 0                                movie_name  ... imdb_score        gross
# 0          0                                    Avatar  ...        7.9  7.60506e+08
# 1          1      Star Wars Ep. VII: The Force Awakens  ...        7.1          NaN
# 2          2  Pirates of the Caribbean: At World's End  ...        7.1  3.09404e+08
# 3          3                                   Spectre  ...        6.8  2.00074e+08
# 4          4                     The Dark Knight Rises  ...        8.5  4.48131e+08
#
# [5 rows x 14 columns]

# %%
with open('/gdrive/My Drive/csv-colab/X.csv', 'w') as f:
  X.to_csv(f)

# %%
from google.colab import files

# %%
X.to_csv('x.csv',index=False)
files.download('x.csv')

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(1,15)
y = np.power(0.11,1.0/x)
plt.plot(x,y)

# %% [markdown]
# **SVM:**
#
# Las máquinas de soporte vectorial, máquinas de vectores de soporte o máquinas de vector soporte (Support Vector Machines, SVMs) son un conjunto de algoritmos de aprendizaje supervisado
#
# Idea Simple:
#
# Dado un conjunto de puntos, subconjunto de un conjunto mayor (espacio), en el que cada uno de ellos pertenece a una de dos posibles categorías, un algoritmo basado en SVM construye un modelo capaz de predecir si un punto nuevo (cuya categoría desconocemos) pertenece a una categoría o a la otra.
